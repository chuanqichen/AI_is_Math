# %% [markdown]
# # Image Noise Reduction Techniques Study

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

figsize = (10, 10)

# %%
original_img = cv2.imread('brain.jpg')
print(original_img.shape)
# Out:
# (537, 537, 3)

# %%
plt.figure(figsize=figsize)
plt.imshow(original_img)

# %% [markdown]
# ## Gaussian Blurring

# %%
gauss = cv2.GaussianBlur(img, (5,5), 0)
plt.figure(figsize=(10, 10))
plt.imshow(gauss)

# %% [markdown]
# ## Median Filter

# %%
ksizes = list(range(1, 31, 2))
for k in ksizes:
    median_filtered = cv2.medianBlur(img, k)
    plt.figure(figsize=(10, 10))
    plt.title('Median filter kernel size: %d'%k)
    plt.imshow(median_filtered)

# %%
# Choose the best kernel size k and update below and conmpare the results with original and gaussian blurred image
k = 3
plt.figure(figsize=(20, 20))
median_filtered = cv2.medianBlur(img, k)
compare = np.concatenate((original_img, gauss, median_filtered), axis=1) #side by side comparison
plt.imshow(compare)

# %% [markdown]
# ## <font color='red'>Homework: Median filter to reduce Noises</font>
# Question:
# *. What're the best parameters so that the noise will go away without lose fidelity of the image ?
#    <br><font color='red'> Answer: Kernel size =  </font>
